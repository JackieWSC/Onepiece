# %%
import pandas as pd

# %%
file_name = '2800_2019_data.json'

# %%
data_frame = pd.read_json(file_name, orient='columns')

# %%
data_frame
# Out:
#      close      code   high    low   open             time_key
# 0    25.25  HK.02800  26.00  25.20  25.95  2019-01-02 00:00:00
# 1    25.25  HK.02800  25.45  25.05  25.35  2019-01-03 00:00:00
# 2    25.80  HK.02800  25.85  25.10  25.15  2019-01-04 00:00:00
# 3    26.05  HK.02800  26.25  25.90  26.20  2019-01-07 00:00:00
# 4    26.00  HK.02800  26.20  25.90  26.10  2019-01-08 00:00:00
# 5    26.65  HK.02800  26.85  26.30  26.30  2019-01-09 00:00:00
# 6    26.75  HK.02800  26.80  26.40  26.60  2019-01-10 00:00:00
# 7    26.80  HK.02800  26.90  26.70  26.85  2019-01-11 00:00:00
# 8    26.45  HK.02800  26.80  26.35  26.80  2019-01-14 00:00:00
# 9    27.00  HK.02800  27.05  26.60  26.60  2019-01-15 00:00:00
# 10   27.10  HK.02800  27.15  26.75  26.90  2019-01-16 00:00:00
# 11   27.00  HK.02800  27.25  26.85  27.10  2019-01-17 00:00:00
# 12   27.25  HK.02800  27.35  27.10  27.20  2019-01-18 00:00:00
# 13   27.35  HK.02800  27.55  27.25  27.30  2019-01-21 00:00:00
# ...

# %%
num_of_row = len(data_frame.index)
previous_k = 0
previous_d = 0b

# %%
data_frame[0:9]
# Out:
#    close      code   high    low   open             time_key
# 0  25.25  HK.02800  26.00  25.20  25.95  2019-01-02 00:00:00
# 1  25.25  HK.02800  25.45  25.05  25.35  2019-01-03 00:00:00
# 2  25.80  HK.02800  25.85  25.10  25.15  2019-01-04 00:00:00
# 3  26.05  HK.02800  26.25  25.90  26.20  2019-01-07 00:00:00
# 4  26.00  HK.02800  26.20  25.90  26.10  2019-01-08 00:00:00
# 5  26.65  HK.02800  26.85  26.30  26.30  2019-01-09 00:00:00
# 6  26.75  HK.02800  26.80  26.40  26.60  2019-01-10 00:00:00
# 7  26.80  HK.02800  26.90  26.70  26.85  2019-01-11 00:00:00
# 8  26.45  HK.02800  26.80  26.35  26.80  2019-01-14 00:00:00

# %%
df_max = data_frame[0:9].max()
df_max
# Out:
# close                      26.8
# code                   HK.02800
# high                       26.9
# low                        26.7
# open                      26.85
# time_key    2019-01-14 00:00:00
# dtype: object

# %%
df_min =  data_frame[0:9].min()
df_min
# Out:
# close                     25.25
# code                   HK.02800
# high                      25.45
# low                       25.05
# open                      25.15
# time_key    2019-01-02 00:00:00
# dtype: object

# %%
data_frame[-8:]
# Out:
#      close      code   high    low   open             time_key
# 238  28.05  HK.02800  28.20  27.95  28.05  2019-12-18 00:00:00
# 239  28.00  HK.02800  28.15  27.85  28.15  2019-12-19 00:00:00
# 240  28.15  HK.02800  28.20  27.95  28.00  2019-12-20 00:00:00
# 241  28.10  HK.02800  28.20  28.00  28.20  2019-12-23 00:00:00
# 242  28.00  HK.02800  28.15  27.95  28.10  2019-12-24 00:00:00
# 243  28.40  HK.02800  28.45  28.20  28.30  2019-12-27 00:00:00
# 244  28.55  HK.02800  28.65  28.35  28.45  2019-12-30 00:00:00
# 245  28.45  HK.02800  28.50  28.30  28.45  2019-12-31 00:00:00

# %%
len(data_frame)
# Out:
# 246

# %%
data_frame.iloc[0]['time_key']
# Out:
# '2019-01-02 00:00:00'
